# %%
import os
import glob
import pandas as pd
from collections import Counter
import numpy as np
from matplotlib import pyplot as plt

from src.dataset import build_dataset

from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Audio feature = CPC

# %%
df_train = pd.read_csv('./feature_cpc_182794_train.csv')
df_test = pd.read_csv('./feature_cpc_182794_test.csv')

X_train = df_train.iloc[:,-128:]
y_train = df_train['label']
X_test = df_test.iloc[:,-128:]
y_test = df_test['label']

# %%
clf = LogisticRegression(max_iter=500, n_jobs=10)
clf.fit(X_train, y_train)

# %%
y_train_pred = clf.predict(X_train)
mat = confusion_matrix(y_train, y_train_pred)
plt.figure(figsize = (10,7))
sns.heatmap(mat, annot=True)
sum(y_train_pred == y_train)/len(y_train)
# Out:
# 0.42542933515604975

# %%
y_test_pred = clf.predict(X_test)
mat = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize = (10,7))
sns.heatmap(mat, annot=True)
sum(y_test_pred == y_test)/len(y_test)
# Out:
# 0.4444150868617478

# %% [markdown]
# ## Audio feature = supervised learning

# %%
df_train = pd.read_csv('./feature_clfvF_160k_train.csv')
df_test = pd.read_csv('./feature_clfvF_160k_test.csv')

X_train = df_train.iloc[:,-128:]
y_train = df_train['label']
X_test = df_test.iloc[:,-128:]
y_test = df_test['label']

# %%
# clf = RandomForestClassifier(max_depth=10, max_features=0.5, n_jobs=10)
clf = LogisticRegression(max_iter=500, n_jobs=10)
clf.fit(X_train, y_train)
# Out:
# /home/msi/app/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=500, n_jobs=10)

# %%
y_train_pred = clf.predict(X_train)
mat = confusion_matrix(y_train, y_train_pred)
plt.figure(figsize = (10,7))
sns.heatmap(mat, annot=True)
sum(y_train_pred == y_train)/len(y_train)
# Out:
# 0.6781847697396526

# %%
y_test_pred = clf.predict(X_test)
mat = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize = (10,7))
sns.heatmap(mat, annot=True)
sum(y_test_pred == y_test)/len(y_test)
# Out:
# 0.6810885791663914
